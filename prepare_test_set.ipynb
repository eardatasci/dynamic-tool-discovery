# %%
import pandas as pd 
import numpy as np
import os
from tqdm import tqdm 
from openai import OpenAI

# %%
client = OpenAI()

# %%
tool_df = pd.read_pickle("data/tool_dataframe.pkl")
df = pd.read_pickle("data/multiple_tools.pkl")

# %%
df.head()
# Out:
#                     id                                           question  \
# 0  live_multiple_0-0-0  [[{'role': 'user', 'content': 'update my latte...
# 1  live_multiple_1-0-1  [[{'role': 'system', 'content': 'You are an ag...
# 2  live_multiple_2-1-0  [[{'role': 'user', 'content': 'Tôi cần một chu...
# 3  live_multiple_3-2-0  [[{'role': 'user', 'content': 'Get weather of ...
# 4  live_multiple_4-2-1  [[{'role': 'user', 'content': 'Tìm chuyến xe c...
#
#                                             function  \
# 0  [{'name': 'ChaFod', 'description': 'Changes th...
# 1  [{'name': 'ChaFod', 'description': 'Changes th...
# 2  [{'name': 'uber_ride', 'description': 'Tìm chu...
# 3  [{'name': 'uber_ride', 'description': 'Finds a...
# 4  [{'name': 'uber_ride', 'description': 'Finds a...
#
#                                         ground_truth
# 0  [{'ChaDri_change_drink': {'drink_id': ['latte'...
# 1  [{'ChaDri_change_drink': {'drink_id': ['1234']...
# 2  [{'uber_ride': {'loc': ['2150 Shattuck Ave, Be...
# 3    [{'api_weather': {'loc': ['Ha Noi, Vietnam']}}]
# 4  [{'uber_ride': {'loc': ['123 Hanoi Street'], '...

# %%
tool_df.head()
# Out:
#                   name                                        description  \
# 0               ChaFod  Changes the food item based on the customer's ...
# 1  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 2               ChaFod  Changes the food item based on the customer's ...
# 3  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 4            uber_ride  Tìm chuyến đi phù hợp cho khách hàng dựa trên ...
#
#                                           parameters
# 0  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 1  {'type': 'dict', 'required': ['new_preferences...
# 2  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 3  {'type': 'dict', 'required': ['drink_id', 'new...
# 4  {'type': 'dict', 'required': ['loc', 'type', '...

# %% [markdown]
# ### Embedding Tool names & descriptions:
# Simple Operation: (tool_df.name + \n + tool_df.description) and embed via OAI embedding-3-large

# %%
tool_df['embedding_input'] = "Name: " + tool_df['name'] + "\n" + "Description: " + tool_df['description']

# %%
def batch(l, n): 
    for i in range(0, len(l), n): 
        yield l[i:i+n]

# %%
embeddings = []

# %%
for x_b in tqdm(batch(tool_df['embedding_input'].tolist(), 100), desc="Embedding..."): 
    response = client.embeddings.create(
        model="text-embedding-3-large",
        input=x_b
    )
    embeddings.extend([item.embedding for item in response.data])
# Out:
# Embedding...: 42it [00:37,  1.13it/s]

# %%
tool_df['embeddings'] = embeddings

# %%
tool_df.head()
tool_df.to_pickle("data/embeddings_tool_df.pkl")

# %% [markdown]
# ### Count Tokens

# %%
import tiktoken 
tool_df['formatted'] = tool_df.apply(lambda row: row.loc[['name', 'description', 'parameters']].to_dict(), axis=1)
tool_df
# Out:
#                       name                                        description  \
# 0                   ChaFod  Changes the food item based on the customer's ...
# 1      ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 2                   ChaFod  Changes the food item based on the customer's ...
# 3      ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 4                uber_ride  Tìm chuyến đi phù hợp cho khách hàng dựa trên ...
# ...                    ...                                                ...
# 4173  Weather_1_GetWeather  Retrieves the weather information for a specif...
# 4174             set_alarm  Set an alarm for a specific time. The time can...
# 4175         set_countdown  Sets a countdown timer for a specified duratio...
# 4176            set_volume  Set the global volume for all audio playback. ...
# 4177             play_song  Plays the requested song based on the provided...
#
#                                              parameters  \
# 0     {'type': 'dict', 'required': ['foodItem'], 'pr...
# 1     {'type': 'dict', 'required': ['new_preferences...
# 2     {'type': 'dict', 'required': ['foodItem'], 'pr...
# 3     {'type': 'dict', 'required': ['drink_id', 'new...
# 4     {'type': 'dict', 'required': ['loc', 'type', '...
# ...                                                 ...
# 4173  {'type': 'dict', 'required': ['city'], 'proper...
# 4174  {'type': 'dict', 'required': ['alarm_time'], '...
# 4175  {'type': 'dict', 'required': ['duration'], 'pr...
# 4176  {'type': 'dict', 'required': ['volume'], 'prop...
# 4177  {'type': 'dict', 'required': ['query'], 'prope...
#
#                                               formatted
# 0     {'name': 'ChaFod', 'description': 'Changes the...
# 1     {'name': 'ChaDri_change_drink', 'description':...
# 2     {'name': 'ChaFod', 'description': 'Changes the...
# 3     {'name': 'ChaDri_change_drink', 'description':...
# 4     {'name': 'uber_ride', 'description': 'Tìm chuy...
# ...                                                 ...
# 4173  {'name': 'Weather_1_GetWeather', 'description'...
# 4174  {'name': 'set_alarm', 'description': 'Set an a...
# 4175  {'name': 'set_countdown', 'description': 'Sets...
# 4176  {'name': 'set_volume', 'description': 'Set the...
# 4177  {'name': 'play_song', 'description': 'Plays th...
#
# [4178 rows x 4 columns]

# %%
encoding = tiktoken.encoding_for_model("gpt-5")
assert encoding.decode(encoding.encode("hello world")) == "hello world" # Checks if model works

# %%
tool_df['n_tokens'] = tool_df['formatted'].apply(lambda x: len(encoding.encode(str(x))))
tool_df["name"] = tool_df["name"].str.replace(".", "_", regex=False)

# %%
tool_df.head()
# Out:
#                   name                                        description  \
# 0               ChaFod  Changes the food item based on the customer's ...
# 1  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 2               ChaFod  Changes the food item based on the customer's ...
# 3  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 4            uber_ride  Tìm chuyến đi phù hợp cho khách hàng dựa trên ...
#
#                                           parameters  \
# 0  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 1  {'type': 'dict', 'required': ['new_preferences...
# 2  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 3  {'type': 'dict', 'required': ['drink_id', 'new...
# 4  {'type': 'dict', 'required': ['loc', 'type', '...
#
#                                            formatted  \
# 0  {'name': 'ChaFod', 'description': 'Changes the...
# 1  {'name': 'ChaDri_change_drink', 'description':...
# 2  {'name': 'ChaFod', 'description': 'Changes the...
# 3  {'name': 'ChaDri_change_drink', 'description':...
# 4  {'name': 'uber_ride', 'description': 'Tìm chuy...
#
#                                           embeddings  n_tokens
# 0  [-0.02990127168595791, -0.012279253453016281, ...       192
# 1  [0.001195563469082117, -0.008156399242579937, ...       332
# 2  [-0.02990127168595791, -0.012279253453016281, ...       192
# 3  [0.001195563469082117, -0.008156399242579937, ...       324
# 4  [-0.007943605072796345, -0.03746823966503143, ...       190

# %%
def to_oai_tool(tool: dict) -> dict:
      TYPE_MAP = {"dict": "object", "float": "number", "any": "string", "tuple": "array"}

      def fix_types(schema: dict) -> dict:
          schema = schema.copy()
          if schema.get("type") in TYPE_MAP:
              schema["type"] = TYPE_MAP[schema["type"]]
          if "properties" in schema:
              schema["properties"] = {
                  k: fix_types(v) for k, v in schema["properties"].items()
              }
          if "items" in schema and isinstance(schema["items"], dict):
              schema["items"] = fix_types(schema["items"])
          return schema

      return {
          "type": "function",
          "name": tool["name"],
          "description": tool["description"],
          "parameters": fix_types(tool["parameters"]),
      }

# %%
tool_df['oai_format'] = tool_df['formatted'].apply(to_oai_tool)
tool_df.head()
# Out:
#                   name                                        description  \
# 0               ChaFod  Changes the food item based on the customer's ...
# 1  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 2               ChaFod  Changes the food item based on the customer's ...
# 3  ChaDri_change_drink  Modifies the existing drink order to accommoda...
# 4            uber_ride  Tìm chuyến đi phù hợp cho khách hàng dựa trên ...
#
#                                           parameters  \
# 0  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 1  {'type': 'dict', 'required': ['new_preferences...
# 2  {'type': 'dict', 'required': ['foodItem'], 'pr...
# 3  {'type': 'dict', 'required': ['drink_id', 'new...
# 4  {'type': 'dict', 'required': ['loc', 'type', '...
#
#                                            formatted  \
# 0  {'name': 'ChaFod', 'description': 'Changes the...
# 1  {'name': 'ChaDri_change_drink', 'description':...
# 2  {'name': 'ChaFod', 'description': 'Changes the...
# 3  {'name': 'ChaDri_change_drink', 'description':...
# 4  {'name': 'uber_ride', 'description': 'Tìm chuy...
#
#                                           embeddings  n_tokens  \
# 0  [-0.02990127168595791, -0.012279253453016281, ...       192
# 1  [0.001195563469082117, -0.008156399242579937, ...       332
# 2  [-0.02990127168595791, -0.012279253453016281, ...       192
# 3  [0.001195563469082117, -0.008156399242579937, ...       324
# 4  [-0.007943605072796345, -0.03746823966503143, ...       190
#
#                                           oai_format
# 0  {'type': 'function', 'name': 'ChaFod', 'descri...
# 1  {'type': 'function', 'name': 'ChaDri_change_dr...
# 2  {'type': 'function', 'name': 'ChaFod', 'descri...
# 3  {'type': 'function', 'name': 'ChaDri_change_dr...
# 4  {'type': 'function', 'name': 'uber_ride', 'des...

# %%
tool_df.n_tokens.describe()
tool_df.to_pickle('data/ntokens_embeddings_tool_df.pkl')
